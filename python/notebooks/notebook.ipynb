# %%
# Append src directory to path
import sys
sys.path.append('C:\\Users\\kingt\\Dropbox\\Programming\\NeuralSimV3\\NeuroSimV3\\python\\src')

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt


from neuron_population import NeuronPopulation
from connectome import Connectome
from overhead import Simulation

# %%
dt = 0.1

# %% [markdown]
# ## Simple test

# %%
# Neuron population parameters
layer_distribution = [400, 400]
n_layers = 2
neuron_types = ["p23", "TRN", "b", "nb"]
n_neuron_types = len(neuron_types)
inhibitory = [False, False, True, True]
dist_layer1 = np.array([60, 20, 10, 10])
dist_layer2 = np.array([40, 40, 10, 10])
neuron_distribution = [dist_layer1, dist_layer2]
threshold_decay = np.exp(-dt / 5)
layer_distances = np.zeros((n_layers, n_layers))
# mm
layer_distances[0, 0] = 0.6
layer_distances[1, 1] = 0.6
layer_distances[0, 1] = 5.0
layer_distances[1, 0] = 5.0

# %%
neuron_pop = NeuronPopulation(
    layer_distribution,
    neuron_distribution,
    layer_distances,
    neuron_types,
    inhibitory,
    threshold_decay,
    threshold_mult=1.15
)

# %%
# Connectome
max_synapses = 400
synapse_strength = np.ones((n_layers, n_layers))
# neuron_types = ["p23", "TRN", "b", "nb"]
connectivity_probability = np.zeros((n_layers, n_layers, n_neuron_types, n_neuron_types))
connectivity_probability[0, 0, 0, 0] = 60
connectivity_probability[0, 0, 1, 0] = 1
connectivity_probability[0, 0, 2, 0] = 9
connectivity_probability[0, 0, 3, 0] = 5

connectivity_probability[0, 0, 0, 0] = 60
connectivity_probability[0, 0, 0, 1] = 1
connectivity_probability[0, 0, 0, 2] = 9
connectivity_probability[0, 0, 0, 3] = 5

connectivity_probability[1, 1, 0, 0] = 60
connectivity_probability[1, 1, 1, 0] = 1
connectivity_probability[1, 1, 2, 0] = 9
connectivity_probability[1, 1, 3, 0] = 5

connectivity_probability[1, 1, 0, 0] = 60
connectivity_probability[1, 1, 0, 1] = 1
connectivity_probability[1, 1, 0, 2] = 9
connectivity_probability[1, 1, 0, 3] = 5

# %%
neuron_pop.type_from_neuron_index(0)
# Out:
# np.str_('p23')

# %%
connectome = Connectome(
    max_synapses,
    neuron_pop,
    connectivity_probability,
    synapse_strength,
)

# %%
sim = Simulation(connectome, dt, stepper_type="adapt")

# %%
# I_ext = 100

# for i in range(3000):
#     sim.step(I_ext=I_ext)

# I_ext = 0

# for i in range(7000):
#     sim.step(I_ext=I_ext)

# for i in range(7000):
#     sim.step(I_ext=I_ext)

# %%
# sim.connectome.W

# %%
import cProfile
import pstats

def your_function():
    I_ext = 100

    for i in range(3000):
        sim.step(I_ext=I_ext)

    # I_ext = 0

    # for i in range(7000):
    #     sim.step(I_ext=I_ext)

    # for i in range(7000):
    #     sim.step(I_ext=I_ext)
    pass

profiler = cProfile.Profile()
profiler.enable()
your_function()
profiler.disable()
stats = pstats.Stats(profiler).sort_stats('cumulative')
stats.print_stats()
# Out:
#          3233124 function calls in 9.168 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    9.155    4.577 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\IPython\core\interactiveshell.py:3541(run_code)
#         2    0.003    0.002    9.155    4.577 {built-in method builtins.exec}
#      3000    0.280    0.000    9.135    0.003 c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\overhead.py:40(step)
#         1    0.000    0.000    8.698    8.698 C:\Users\kingt\AppData\Local\Temp\ipykernel_25728\1791343088.py:1(<module>)
#         1    0.005    0.005    8.698    8.698 C:\Users\kingt\AppData\Local\Temp\ipykernel_25728\1791343088.py:4(your_function)
#      3000    5.796    0.002    5.820    0.002 c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\plasticity.py:305(step)
#      3000    1.353    0.000    1.385    0.000 c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\synapse_dynamics.py:77(spike_input)
#      3000    0.420    0.000    0.982    0.000 c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\axonal_dynamics.py:34(check)
#      3000    0.410    0.000    0.519    0.000 c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\axonal_dynamics.py:21(push_many)
#   1040401    0.490    0.000    0.490    0.000 {built-in method _heapq.heappop}
#         1    0.013    0.013    0.453    0.453 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\base_events.py:1953(_run_once)
#      3000    0.098    0.000    0.109    0.000 c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\izhikevich.py:102(IZ_Neuron_stepper_adapt)
#   1040401    0.097    0.000    0.097    0.000 {built-in method _heapq.heappush}
#   1052400    0.073    0.000    0.073    0.000 {method 'append' of 'list' objects}
#      9000    0.032    0.000    0.032    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      3000    0.004    0.000    0.031    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\numpy\_core\fromnumeric.py:2611(all)
#      3000    0.006    0.000    0.028    0.000 c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\input_integration.py:11(__call__)
#      3000    0.007    0.000    0.027    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\numpy\_core\fromnumeric.py:89(_wrapreduction_any_all)
#      3000    0.022    0.000    0.022    0.000 c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\plasticity.py:18(step)
#      3000    0.019    0.000    0.021    0.000 c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\synapse_dynamics.py:104(__call__)
#      6000    0.013    0.000    0.013    0.000 {built-in method numpy.zeros}
#      3000    0.001    0.000    0.009    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      3000    0.002    0.000    0.009    0.000 {method 'any' of 'numpy.ndarray' objects}
#      3000    0.001    0.000    0.008    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\numpy\_core\_methods.py:51(_sum)
#      3000    0.001    0.000    0.007    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\numpy\_core\_methods.py:59(_any)
#      9000    0.006    0.000    0.006    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      3000    0.005    0.000    0.005    0.000 c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\synapse_dynamics.py:71(decay)
#       440    0.001    0.000    0.002    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\ipykernel\ipkernel.py:775(_clean_thread_parent_frames)
#      3000    0.002    0.000    0.002    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\numba\core\serialize.py:30(_numba_unpickle)
#      7892    0.002    0.000    0.002    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.002    0.002 c:\Users\kingt\anaconda3\envs\neuro\Lib\selectors.py:310(select)
#         1    0.000    0.000    0.002    0.002 c:\Users\kingt\anaconda3\envs\neuro\Lib\selectors.py:304(_select)
#         1    0.002    0.002    0.002    0.002 {built-in method select.select}
#      3001    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#       220    0.000    0.000    0.001    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\threading.py:1477(enumerate)
#      3000    0.001    0.000    0.001    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\numpy\_core\fromnumeric.py:2606(_all_dispatcher)
#      3946    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\numpy\_core\multiarray.py:910(bincount)
#      1540    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\threading.py:1110(ident)
#      2176    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\numpy\_core\multiarray.py:363(where)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#       550    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       880    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\events.py:87(_run)
#         2    0.000    0.000    0.000    0.000 {method 'run' of '_contextvars.Context' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\codeop.py:113(__call__)
#       440    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:3631(set)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\ipykernel\iostream.py:118(_run_event_pipe_gc)
#       447    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:689(set)
#       220    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\tasks.py:703(sleep)
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\ipykernel\iostream.py:127(_event_pipe_gc)
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\futures.py:310(_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\base_events.py:776(call_later)
#         4    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\contextlib.py:303(helper)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\base_events.py:800(call_at)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:1527(_notify_observers)
#         3    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\threading.py:1134(is_alive)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\base_events.py:818(call_soon)
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\contextlib.py:145(__exit__)
#         4    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\base_events.py:767(time)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\events.py:157(cancel)
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\events.py:113(__init__)
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\contextlib.py:108(__init__)
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\events.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\base_events.py:847(_call_soon)
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\contextlib.py:136(__enter__)
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:727(_cross_validate)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         4    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\IPython\core\history.py:839(_writeout_output_cache)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\base_events.py:457(create_future)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\threading.py:318(_is_owned)
#         4    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\IPython\core\compilerop.py:180(extra_flags)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\threading.py:312(_release_save)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\threading.py:303(__enter__)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         6    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#        18    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\typing.py:2367(cast)
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\traitlets\traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\events.py:73(cancel)
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\IPython\core\interactiveshell.py:3493(compare)
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method math.isnan}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\selector_events.py:740(_process_events)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\site-packages\IPython\core\interactiveshell.py:1277(user_global_ns)
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\base_events.py:549(_check_closed)
#         4    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\base_events.py:2051(get_debug)
#         3    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 c:\Users\kingt\anaconda3\envs\neuro\Lib\asyncio\base_events.py:1948(_timer_handle_cancelled)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}

# %%
# neuron_pop.get_types_from_layer(0)
# neuron_pop.get_neurons_from_layer(0)

# %%
plt.plot(np.array(sim.stats.Vs)[:, neuron_pop.get_neurons_from_layer(1)])
plt.show()

# %% [markdown]
# ## Cortical column

# %%
n_neurons = 500
max_synapses = 300
n_layers = 6

layer_percentages = [1.5, 26 + 3.1 + 4.2, 9.2 + 9.2 + 9.2 + 5.4 + 1.5, 4.8 + 1.3 + 0.6 + 0.8,
                     13.6 + 4.5 + 2 + 2, 0.5 + 0.5 + 0.1 + 0.1 + 0.5]

layer_dist = list(np.array(layer_percentages) / 100.0 * n_neurons)
# Convert elements to integers, rounding down
neurons_per_layer = [int(np.floor(x)) for x in layer_dist]
n_neurons = sum(neurons_per_layer)

# %%
neuron_types = ["nb1", "p23", "b", "nb", "ss4", "p4", "p5_p6", "TC", "TI", "TRN"]
n_neuron_types = len(neuron_types)
inhibitory = [True, False, True, True, False, False, False, False, True, True]

# %%
dist_layers = np.zeros((n_layers, n_neuron_types))
dist_layers[0, 0] = 1.0

dist_layers[1, 1] = 26.0
dist_layers[1, 2] = 3.1
dist_layers[1, 3] = 4.2

dist_layers[2, 2] = 5.4
dist_layers[2, 3] = 1.5
dist_layers[2, 4] = 9.2 + 9.2
dist_layers[2, 5] = 9.2

dist_layers[3, 6] = 4.8 + 1.3
dist_layers[3, 2] = 0.6
dist_layers[3, 3] = 0.8

dist_layers[4, 6] = 4.5
dist_layers[4, 2] = 2
dist_layers[4, 3] = 2

dist_layers[5, 7] = 1
dist_layers[5, 8] = 0.2
dist_layers[5, 9] = 0.5

# %%
layer_distances = np.zeros((n_layers, n_layers))
# mm
# Fill diagonal with 0.6 mm (vectorized)
layer_distances[np.diag_indices(n_layers)] = 0.3
# Fill all other elements with the difference of the index times 0.6
for i in range(n_layers):
    for j in range(n_layers):
        if i != j:
            layer_distances[i, j] = abs(i - j) * 0.6

layer_distances
# Out:
# array([[0.3, 0.6, 1.2, 1.8, 2.4, 3. ],
#        [0.6, 0.3, 0.6, 1.2, 1.8, 2.4],
#        [1.2, 0.6, 0.3, 0.6, 1.2, 1.8],
#        [1.8, 1.2, 0.6, 0.3, 0.6, 1.2],
#        [2.4, 1.8, 1.2, 0.6, 0.3, 0.6],
#        [3. , 2.4, 1.8, 1.2, 0.6, 0.3]])

# %%
synapse_strength = np.ones((n_layers, n_layers))

# %%
threshold_decay = np.exp(-dt / 10)

neuron_pop = NeuronPopulation(
    neurons_per_layer,
    dist_layers,
    layer_distances,
    neuron_types,
    inhibitory,
    threshold_decay,
    threshold_mult=1.5
)

# %%
neuron_pop.n_neurons
# Out:
# 500

# %%
C = np.load("connectivity_matrix.npy")

# a zero array to last dimension
connectivity_probability = np.zeros((n_layers, n_layers, n_neuron_types, n_neuron_types+2))

# Fill the connectivity probability matrix with the values from C
connectivity_probability[:,:,:,:-2] = C[:,:,:,:]

connectivity_probability[:,:,:,-2] = 1.0  # Self connections
connectivity_probability[:,:,:,-1] = 0.0  # No empty connections

# %%
connectome = Connectome(
    max_synapses,
    neuron_pop,
    connectivity_probability,
    synapse_strength,
)

# %%
sim = Simulation(connectome, dt, stepper_type="adapt")

# %%
# import cProfile
# import pstats

# def your_function():
#     I_ext = 30
#     for i in range(100):
#         sim.step(I_ext=I_ext)
#     pass

# profiler = cProfile.Profile()
# profiler.enable()
# your_function()
# profiler.disable()
# stats = pstats.Stats(profiler).sort_stats('cumulative')
# stats.print_stats()

# %%
I_ext = 100

for i in range(500):
    sim.step(I_ext=I_ext)

I_ext = 0

for i in range(1500):
    sim.step(I_ext=I_ext)
# Out:
# c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\izhikevich.py:115: RuntimeWarning: overflow encountered in exp
#   spike_prob = dt * np.exp((self.V - eff_threshold) / self.delta_V)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[200], line 4
#       1 I_ext = 100
#       3 for i in range(500):
# ----> 4     sim.step(I_ext=I_ext)
#       6 I_ext = 0
#       8 for i in range(1500):
#
# File c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\overhead.py:49, in Simulation.step(self, I_ext)
#      47 post_spikes = self.neuron_states.spike # shape n_neurons x 1
#      48 # Update the axonal dynamics
# ---> 49 pre_spikes = self.axonal_dynamics.check(self.t_now + self.dt) # shape n_neurons x max_synapses
#      50 # Push the spikes to the axonal dynamics, do it after the pre_spikes are checked,
#      51 # as the spikes comes from the end of the current step
#      52 self.axonal_dynamics.push_many(post_spikes, self.t_now + self.dt)
#
# File c:\Users\kingt\Dropbox\Programming\NeuralSimV3\NeuroSimV3\python\src\axonal_dynamics.py:37, in AxonalDynamics.check(self, t_now)
#      35 arrived = []
#      36 heap = self._heap
# ---> 37 while heap and heap[0][0] <= t_now:
#      38     _, i, j = heapq.heappop(heap)
#      39     arrived.append((i, j))
#
# KeyboardInterrupt:

# %%
neuron_pop.get_types_from_layer(0)
neuron_pop.get_neurons_from_layer(0)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
np.array(sim.stats.Vs).shape
# Out:
# (2001, 500)

# %%
neuron_pop.get_neurons_from_layer(0).shape
# Out:
# (7,)

# %%
np.array(sim.stats.Vs)[:, neuron_pop.get_neurons_from_layer(0)].shape
# Out:
# (2001, 7)

# %%
np.array(sim.stats.spikes).shape

spikes_sum = np.sum(np.array(sim.stats.spikes), axis=0)
spikes_sum.shape
# Out:
# (500,)

# %%
spiker = np.argmax(spikes_sum)
neuron_pop.type_from_neuron_index(spiker)
# neuron_pop.get_layer(spiker)
# spikes_sum[spiker]
# Out:
# np.str_('ss4')

# %%
plt.plot(sim.stats.ts, np.array(sim.stats.Vs)[:, neuron_pop.get_neurons_from_layer(2)])
# plt.plot(sim.stats.ts, np.array(sim.stats.Vs)[:,spiker])
plt.show()
